# %%
import requests
from bs4 import BeautifulSoup
import random

# response object as the webpage
response = requests.get(
                        url= "https://en.wikipedia.org/wiki/Web_scraping"
) 

#check status code
print(f'Response Status Code: {response.status_code}')
# Out:
# Response Status Code: 200

# %%
def scrapeWikiArticle(url):
	response = requests.get(
		url=url,
	)
	
	soup = BeautifulSoup(response.content, 'html.parser')

	title = soup.find(id="firstHeading")
	print(title.text)

	allLinks = soup.find(id="bodyContent").find_all("a")
	random.shuffle(allLinks)
	linkToScrape = 0

	for link in allLinks:
		# We are only interested in other wiki articles
		if link['href'].find("/wiki/") == -1: 
			continue

		# Use this link to scrape
		linkToScrape = link
		break

	scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])

scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
# Out:
# Web scraping
# Electronic Frontier Foundation
# Techdirt
# Glyn Moody
# Category:Use dmy dates from April 2022
# 3 Hammers
# Rice wine
# Apo (drink)
# Brahmaputra Valley
# Garo people
# Dagger
# Kitchen knife
# Yatagan
# Kopis
# Shashka
# Classification of swords
# Book sources
# Concordia College (Moorhead, Minnesota)
# Adolph Murie
# Template:Cite journal
# Help:Footnotes
# Template:Reflist
# Template:Search templates
# Template:ShortSearch
# Help:Category
# Help:Displaying a formula
# Wikipedia:Books
# Help:Talk pages
# Wikipedia:Talk page guidelines
# Wikipedia:Revision deletion
# Wikipedia:Questions
# Help:HTML in wikitext
# Wikipedia:Manual of Style
# Wikipedia:Shortcut
# All pages with prefix
# WikiProject
# Interpedia
# Wapedia
# iPhone
# Ticker tape
# Edison Machine Works
# Etheric force
# Book sources
# Commission on Higher Education (Philippines)
# Filipino language
# Abaknon language
# Idne language
# Adzera language
# Bariai language
# Kanowit language
# Badaic languages
# Malay language
# Affix
# Reduplication
# Onomatopoeia
# Tic Tac
# Ferrero SpA
# Pietro Ferrero
# Category:20th-century Italian businesspeople
# Ferruccio Lamborghini
# Template:Lamborghini
# Lamborghini Espada
# Help:Category
# Wikipedia:Categorizing redirects
# Template:Talk page of redirect
# Template:R from ambiguous term
# Template:R to subtopic
# Template:R from draft namespace
# Template:R from draft namespace/doc
# Wikipedia:Categorization
# Wikipedia:Stub
# Wikipedia:WikiProject Stub sorting/Stub types
# Template:Germany-painter-stub
# Wikipedia:Stub
# Wikipedia:Manual of Style/Medicine-related articles
# Wikipedia:Manual of Style/Snooker
# Wikipedia:Manual of Style/Images
# Wikipedia:Finding images tutorial
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\Users\brend\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# c:\Users\brend\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# c:\Users\brend\AppData\Local\Programs\Python\Python310\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     954     addrlist = []
# --> 955     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# c:\Users\brend\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# c:\Users\brend\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# c:\Users\brend\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# c:\Users\brend\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connection.py in connect(self)
#     357         # Add certificate verification
# --> 358         conn = self._new_conn()
#     359         hostname = self.host
#
# c:\Users\brend\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x0000027CBB7471C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\Users\brend\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# c:\Users\brend\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# c:\Users\brend\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPSConnectionPool(host='en.wikipedia.orghttps', port=443): Max retries exceeded with url: //commons.wikimedia.org/wiki/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000027CBB7471C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in <module>
#      24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
# ---> 26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#      22                 break
#      23
# ---> 24         scrapeWikiArticle("https://en.wikipedia.org" + linkToScrape['href'])
#      25
#      26 scrapeWikiArticle("https://en.wikipedia.org/wiki/Web_scraping")
#
# ~\AppData\Local\Temp/ipykernel_16932/3971909324.py in scrapeWikiArticle(url)
#       1 def scrapeWikiArticle(url):
# ----> 2 	response = requests.get(
#       3                 url=url,
#       4 	)
#       5
#
# c:\Users\brend\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# c:\Users\brend\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# c:\Users\brend\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\Users\brend\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\Users\brend\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='en.wikipedia.orghttps', port=443): Max retries exceeded with url: //commons.wikimedia.org/wiki/ (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000027CBB7471C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
